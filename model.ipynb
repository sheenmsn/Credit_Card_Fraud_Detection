# %% [markdown]
# # Credit Card Fraud Detection

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from catboost import CatBoostClassifier
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import GridSearchCV
import pickle

# %%
# Loading dataset
raw_data_url = 'https://github.com/sheenmsn/Credit_Card_Fraud_Detection/raw/main/Data/creditcard.csv'
dataset = pd.read_csv(raw_data_url)

# %%
# Display basic information about the dataset
dataset
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
# Check if any duplicate rows exist in the dataframe
duplicates_exist = dataset.duplicated().any()
print('Duplicate rows exist:', duplicates_exist)
print(f'Number of duplicate rows: {dataset.duplicated().sum()}')
dataset.drop_duplicates(inplace=True)
# Out:
# Duplicate rows exist: True
# Number of duplicate rows: 1081

# %% [markdown]
# Removed the duplicate rows

# %%
dataset.shape
# Out:
# (283726, 31)

# %% [markdown]
# # Predictive models

# %%
# Dropping the column Time as it is not impactful
dataset = dataset.drop(['Time'], axis=1)
dataset.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 30 columns]

# %%
# Scaling the feature "Amount" for better result
sc = StandardScaler()
amount = dataset['Amount'].values

dataset['Amount'] = sc.fit_transform(amount.reshape(-1, 1))
dataset.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  0.244200      0
# 1  0.167170  0.125895 -0.008983  0.014724 -0.342584      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  1.158900      0
# 3  0.647376 -0.221929  0.062723  0.061458  0.139886      0
# 4 -0.206010  0.502292  0.219422  0.215153 -0.073813      0
#
# [5 rows x 30 columns]

# %%
# Define target and predictor values
x = dataset.drop('Class', axis=1)
y = dataset['Class']

# %% [markdown]
# ### Split data in train and, test set

# %%
VALID_SIZE = 0.20
TEST_SIZE = 0.20
RANDOM_STATE = 42

# %%
# Splitting data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=TEST_SIZE, random_state=RANDOM_STATE, shuffle=True )

# %% [markdown]
# # SMOTE (Synthetic Minority Over-sampling Technique)

# %%
from imblearn.over_sampling import SMOTE

# Resample the dataset using SMOTE
smote = SMOTE(random_state=RANDOM_STATE)

# Resample the training dataset using SMOTE
x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

# %% [markdown]
# ### Skewness Correction and Transformation with PowerTransformer

# %%
# Correcting skewness using PowerTransformer

ptf = PowerTransformer(method='yeo-johnson', standardize=True, copy=True)
x_train_smote = ptf.fit_transform(x_train_smote)
x_test = ptf.transform(x_test)

# %% [markdown]
# ## CatBoostClassifier Hyperparameter Tuning

# %%
cbc_param_grid = {
    'iterations': [500],
    'learning_rate': [0.01, 0.05],
    'depth': [6, 8]
}

# %%
# Initialize CatBoostClassifier
cbc = CatBoostClassifier(random_seed=RANDOM_STATE,
                         bagging_temperature=0.2,
                         od_type='Iter',
                         od_wait=100,
                         eval_metric='AUC')

# %%
cbc_grid_search = GridSearchCV(estimator=cbc,
                               param_grid=cbc_param_grid,
                               scoring='roc_auc',
                               cv=3,
                               n_jobs=-1,
                               verbose=1)

# %%
cbc_grid_search.fit(x_train_smote, y_train_smote)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# 0:	total: 364ms	remaining: 3m 1s
# 1:	total: 607ms	remaining: 2m 31s
# 2:	total: 830ms	remaining: 2m 17s
# 3:	total: 1.04s	remaining: 2m 9s
# 4:	total: 1.26s	remaining: 2m 4s
# 5:	total: 1.47s	remaining: 2m
# 6:	total: 1.67s	remaining: 1m 57s
# 7:	total: 1.87s	remaining: 1m 55s
# 8:	total: 2.08s	remaining: 1m 53s
# 9:	total: 2.28s	remaining: 1m 51s
# 10:	total: 2.5s	remaining: 1m 51s
# 11:	total: 2.69s	remaining: 1m 49s
# 12:	total: 2.9s	remaining: 1m 48s
# 13:	total: 3.09s	remaining: 1m 47s
# 14:	total: 3.29s	remaining: 1m 46s
# 15:	total: 3.47s	remaining: 1m 44s
# 16:	total: 3.67s	remaining: 1m 44s
# 17:	total: 3.88s	remaining: 1m 43s
# 18:	total: 4.09s	remaining: 1m 43s
# 19:	total: 4.28s	remaining: 1m 42s
# 20:	total: 4.51s	remaining: 1m 42s
# 21:	total: 4.71s	remaining: 1m 42s
# 22:	total: 4.89s	remaining: 1m 41s
# 23:	total: 5.09s	remaining: 1m 40s
# 24:	total: 5.28s	remaining: 1m 40s
# 25:	total: 5.46s	remaining: 1m 39s
# 26:	total: 5.67s	remaining: 1m 39s
# 27:	total: 5.88s	remaining: 1m 39s
# 28:	total: 6.09s	remaining: 1m 38s
# 29:	total: 6.29s	remaining: 1m 38s
# 30:	total: 6.49s	remaining: 1m 38s
# 31:	total: 6.71s	remaining: 1m 38s
# 32:	total: 6.91s	remaining: 1m 37s
# 33:	total: 7.13s	remaining: 1m 37s
# 34:	total: 7.33s	remaining: 1m 37s
# 35:	total: 7.55s	remaining: 1m 37s
# 36:	total: 7.74s	remaining: 1m 36s
# 37:	total: 7.94s	remaining: 1m 36s
# 38:	total: 8.13s	remaining: 1m 36s
# 39:	total: 8.34s	remaining: 1m 35s
# 40:	total: 8.53s	remaining: 1m 35s
# 41:	total: 8.74s	remaining: 1m 35s
# 42:	total: 8.93s	remaining: 1m 34s
# 43:	total: 9.12s	remaining: 1m 34s
# 44:	total: 9.3s	remaining: 1m 34s
# 45:	total: 9.51s	remaining: 1m 33s
# 46:	total: 9.72s	remaining: 1m 33s
# 47:	total: 9.93s	remaining: 1m 33s
# 48:	total: 10.1s	remaining: 1m 33s
# 49:	total: 10.4s	remaining: 1m 33s
# 50:	total: 10.6s	remaining: 1m 32s
# 51:	total: 10.8s	remaining: 1m 32s
# 52:	total: 11s	remaining: 1m 32s
# 53:	total: 11.2s	remaining: 1m 32s
# 54:	total: 11.4s	remaining: 1m 31s
# 55:	total: 11.6s	remaining: 1m 31s
# 56:	total: 11.8s	remaining: 1m 31s
# 57:	total: 12s	remaining: 1m 31s
# 58:	total: 12.2s	remaining: 1m 31s
# 59:	total: 12.4s	remaining: 1m 30s
# 60:	total: 12.6s	remaining: 1m 30s
# 61:	total: 12.8s	remaining: 1m 30s
# 62:	total: 13s	remaining: 1m 30s
# 63:	total: 13.2s	remaining: 1m 29s
# 64:	total: 13.4s	remaining: 1m 29s
# 65:	total: 13.6s	remaining: 1m 29s
# 66:	total: 13.8s	remaining: 1m 28s
# 67:	total: 13.9s	remaining: 1m 28s
# 68:	total: 14.1s	remaining: 1m 28s
# 69:	total: 14.3s	remaining: 1m 27s
# 70:	total: 14.5s	remaining: 1m 27s
# 71:	total: 14.7s	remaining: 1m 27s
# 72:	total: 14.9s	remaining: 1m 27s
# 73:	total: 15.1s	remaining: 1m 26s
# 74:	total: 15.3s	remaining: 1m 26s
# 75:	total: 15.5s	remaining: 1m 26s
# 76:	total: 15.7s	remaining: 1m 26s
# 77:	total: 15.9s	remaining: 1m 26s
# 78:	total: 16.2s	remaining: 1m 26s
# 79:	total: 16.4s	remaining: 1m 25s
# 80:	total: 16.6s	remaining: 1m 25s
# 81:	total: 16.7s	remaining: 1m 25s
# 82:	total: 16.9s	remaining: 1m 25s
# 83:	total: 17.1s	remaining: 1m 24s
# 84:	total: 17.3s	remaining: 1m 24s
# 85:	total: 17.5s	remaining: 1m 24s
# 86:	total: 17.7s	remaining: 1m 24s
# 87:	total: 17.9s	remaining: 1m 23s
# 88:	total: 18.1s	remaining: 1m 23s
# 89:	total: 18.3s	remaining: 1m 23s
# 90:	total: 18.5s	remaining: 1m 23s
# 91:	total: 18.6s	remaining: 1m 22s
# 92:	total: 18.8s	remaining: 1m 22s
# 93:	total: 19s	remaining: 1m 22s
# 94:	total: 19.2s	remaining: 1m 21s
# 95:	total: 19.4s	remaining: 1m 21s
# 96:	total: 19.6s	remaining: 1m 21s
# 97:	total: 19.8s	remaining: 1m 21s
# 98:	total: 20.1s	remaining: 1m 21s
# 99:	total: 20.2s	remaining: 1m 20s
# 100:	total: 20.4s	remaining: 1m 20s
# 101:	total: 20.6s	remaining: 1m 20s
# 102:	total: 20.8s	remaining: 1m 20s
# 103:	total: 21s	remaining: 1m 19s
# 104:	total: 21.1s	remaining: 1m 19s
# 105:	total: 21.3s	remaining: 1m 19s
# 106:	total: 21.5s	remaining: 1m 19s
# 107:	total: 21.7s	remaining: 1m 18s
# 108:	total: 21.9s	remaining: 1m 18s
# 109:	total: 22.1s	remaining: 1m 18s
# 110:	total: 22.2s	remaining: 1m 17s
# 111:	total: 22.4s	remaining: 1m 17s
# 112:	total: 22.6s	remaining: 1m 17s
# 113:	total: 22.8s	remaining: 1m 17s
# 114:	total: 23s	remaining: 1m 16s
# 115:	total: 23.1s	remaining: 1m 16s
# 116:	total: 23.3s	remaining: 1m 16s
# 117:	total: 23.5s	remaining: 1m 16s
# 118:	total: 23.7s	remaining: 1m 15s
# 119:	total: 23.8s	remaining: 1m 15s
# 120:	total: 24s	remaining: 1m 15s
# 121:	total: 24.2s	remaining: 1m 15s
# 122:	total: 24.4s	remaining: 1m 14s
# 123:	total: 24.6s	remaining: 1m 14s
# 124:	total: 24.8s	remaining: 1m 14s
# 125:	total: 24.9s	remaining: 1m 13s
# 126:	total: 25.1s	remaining: 1m 13s
# 127:	total: 25.3s	remaining: 1m 13s
# 128:	total: 25.5s	remaining: 1m 13s
# 129:	total: 25.6s	remaining: 1m 12s
# 130:	total: 25.9s	remaining: 1m 12s
# 131:	total: 26s	remaining: 1m 12s
# 132:	total: 26.2s	remaining: 1m 12s
# 133:	total: 26.4s	remaining: 1m 12s
# 134:	total: 26.6s	remaining: 1m 12s
# 135:	total: 26.8s	remaining: 1m 11s
# 136:	total: 27s	remaining: 1m 11s
# 137:	total: 27.2s	remaining: 1m 11s
# 138:	total: 27.4s	remaining: 1m 11s
# 139:	total: 27.5s	remaining: 1m 10s
# 140:	total: 27.8s	remaining: 1m 10s
# 141:	total: 28s	remaining: 1m 10s
# 142:	total: 28.1s	remaining: 1m 10s
# 143:	total: 28.3s	remaining: 1m 10s
# 144:	total: 28.5s	remaining: 1m 9s
# 145:	total: 28.7s	remaining: 1m 9s
# 146:	total: 28.9s	remaining: 1m 9s
# 147:	total: 29.1s	remaining: 1m 9s
# 148:	total: 29.3s	remaining: 1m 9s
# 149:	total: 29.5s	remaining: 1m 8s
# 150:	total: 29.9s	remaining: 1m 9s
# 151:	total: 30.3s	remaining: 1m 9s
# 152:	total: 30.8s	remaining: 1m 9s
# 153:	total: 32.1s	remaining: 1m 12s
# 154:	total: 32.6s	remaining: 1m 12s
# 155:	total: 32.9s	remaining: 1m 12s
# 156:	total: 33.1s	remaining: 1m 12s
# 157:	total: 33.4s	remaining: 1m 12s
# 158:	total: 33.6s	remaining: 1m 12s
# 159:	total: 34s	remaining: 1m 12s
# 160:	total: 34.2s	remaining: 1m 11s
# 161:	total: 34.9s	remaining: 1m 12s
# 162:	total: 35.3s	remaining: 1m 12s
# 163:	total: 35.5s	remaining: 1m 12s
# 164:	total: 35.8s	remaining: 1m 12s
# 165:	total: 36.1s	remaining: 1m 12s
# 166:	total: 36.3s	remaining: 1m 12s
# 167:	total: 36.6s	remaining: 1m 12s
# 168:	total: 36.8s	remaining: 1m 12s
# 169:	total: 37s	remaining: 1m 11s
# 170:	total: 37.2s	remaining: 1m 11s
# 171:	total: 37.4s	remaining: 1m 11s
# 172:	total: 37.6s	remaining: 1m 11s
# 173:	total: 37.8s	remaining: 1m 10s
# 174:	total: 38s	remaining: 1m 10s
# 175:	total: 38.2s	remaining: 1m 10s
# 176:	total: 38.4s	remaining: 1m 10s
# 177:	total: 38.7s	remaining: 1m 10s
# 178:	total: 39s	remaining: 1m 9s
# 179:	total: 39.4s	remaining: 1m 9s
# 180:	total: 39.6s	remaining: 1m 9s
# 181:	total: 39.8s	remaining: 1m 9s
# 182:	total: 40s	remaining: 1m 9s
# 183:	total: 40.3s	remaining: 1m 9s
# 184:	total: 40.4s	remaining: 1m 8s
# 185:	total: 40.7s	remaining: 1m 8s
# 186:	total: 41.1s	remaining: 1m 8s
# 187:	total: 41.4s	remaining: 1m 8s
# 188:	total: 41.9s	remaining: 1m 9s
# 189:	total: 42.3s	remaining: 1m 8s
# 190:	total: 42.6s	remaining: 1m 8s
# 191:	total: 42.9s	remaining: 1m 8s
# 192:	total: 43.3s	remaining: 1m 8s
# 193:	total: 43.5s	remaining: 1m 8s
# 194:	total: 43.8s	remaining: 1m 8s
# 195:	total: 44.2s	remaining: 1m 8s
# 196:	total: 44.4s	remaining: 1m 8s
# 197:	total: 44.6s	remaining: 1m 8s
# 198:	total: 45.2s	remaining: 1m 8s
# 199:	total: 45.7s	remaining: 1m 8s
# 200:	total: 46.1s	remaining: 1m 8s
# 201:	total: 46.4s	remaining: 1m 8s
# 202:	total: 46.8s	remaining: 1m 8s
# 203:	total: 47s	remaining: 1m 8s
# 204:	total: 47.4s	remaining: 1m 8s
# 205:	total: 47.7s	remaining: 1m 8s
# 206:	total: 48.2s	remaining: 1m 8s
# 207:	total: 48.6s	remaining: 1m 8s
# 208:	total: 49s	remaining: 1m 8s
# 209:	total: 49.4s	remaining: 1m 8s
# 210:	total: 49.7s	remaining: 1m 8s
# 211:	total: 50.1s	remaining: 1m 8s
# 212:	total: 50.5s	remaining: 1m 8s
# 213:	total: 50.9s	remaining: 1m 8s
# 214:	total: 51.1s	remaining: 1m 7s
# 215:	total: 51.3s	remaining: 1m 7s
# 216:	total: 51.5s	remaining: 1m 7s
# 217:	total: 51.7s	remaining: 1m 6s
# 218:	total: 52s	remaining: 1m 6s
# 219:	total: 52.2s	remaining: 1m 6s
# 220:	total: 52.4s	remaining: 1m 6s
# 221:	total: 52.6s	remaining: 1m 5s
# 222:	total: 52.8s	remaining: 1m 5s
# 223:	total: 53s	remaining: 1m 5s
# 224:	total: 53.2s	remaining: 1m 5s
# 225:	total: 53.4s	remaining: 1m 4s
# 226:	total: 53.6s	remaining: 1m 4s
# 227:	total: 53.8s	remaining: 1m 4s
# 228:	total: 54.1s	remaining: 1m 3s
# 229:	total: 54.2s	remaining: 1m 3s
# 230:	total: 54.4s	remaining: 1m 3s
# 231:	total: 54.6s	remaining: 1m 3s
# 232:	total: 54.8s	remaining: 1m 2s
# 233:	total: 55s	remaining: 1m 2s
# 234:	total: 55.2s	remaining: 1m 2s
# 235:	total: 55.4s	remaining: 1m 1s
# 236:	total: 55.6s	remaining: 1m 1s
# 237:	total: 55.8s	remaining: 1m 1s
# 238:	total: 56s	remaining: 1m 1s
# 239:	total: 56.1s	remaining: 1m
# 240:	total: 56.3s	remaining: 1m
# 241:	total: 56.5s	remaining: 1m
# 242:	total: 56.7s	remaining: 59.9s
# 243:	total: 56.8s	remaining: 59.6s
# 244:	total: 57s	remaining: 59.3s
# 245:	total: 57.2s	remaining: 59s
# 246:	total: 57.4s	remaining: 58.8s
# 247:	total: 57.5s	remaining: 58.5s
# 248:	total: 57.7s	remaining: 58.1s
# 249:	total: 57.8s	remaining: 57.8s
# 250:	total: 58s	remaining: 57.6s
# 251:	total: 58.2s	remaining: 57.3s
# 252:	total: 58.4s	remaining: 57s
# 253:	total: 58.6s	remaining: 56.7s
# 254:	total: 58.7s	remaining: 56.4s
# 255:	total: 58.9s	remaining: 56.1s
# 256:	total: 59.1s	remaining: 55.9s
# 257:	total: 59.3s	remaining: 55.6s
# 258:	total: 59.4s	remaining: 55.3s
# 259:	total: 59.6s	remaining: 55s
# 260:	total: 59.8s	remaining: 54.7s
# 261:	total: 59.9s	remaining: 54.5s
# 262:	total: 1m	remaining: 54.2s
# 263:	total: 1m	remaining: 53.9s
# 264:	total: 1m	remaining: 53.7s
# 265:	total: 1m	remaining: 53.4s
# 266:	total: 1m	remaining: 53.1s
# 267:	total: 1m 1s	remaining: 52.8s
# 268:	total: 1m 1s	remaining: 52.6s
# 269:	total: 1m 1s	remaining: 52.3s
# 270:	total: 1m 1s	remaining: 52s
# 271:	total: 1m 1s	remaining: 51.8s
# 272:	total: 1m 1s	remaining: 51.5s
# 273:	total: 1m 2s	remaining: 51.2s
# 274:	total: 1m 2s	remaining: 51s
# 275:	total: 1m 2s	remaining: 50.7s
# 276:	total: 1m 2s	remaining: 50.4s
# 277:	total: 1m 2s	remaining: 50.1s
# 278:	total: 1m 2s	remaining: 49.9s
# 279:	total: 1m 3s	remaining: 49.6s
# 280:	total: 1m 3s	remaining: 49.3s
# 281:	total: 1m 3s	remaining: 49.1s
# 282:	total: 1m 3s	remaining: 48.8s
# 283:	total: 1m 3s	remaining: 48.5s
# 284:	total: 1m 4s	remaining: 48.3s
# 285:	total: 1m 4s	remaining: 48s
# 286:	total: 1m 4s	remaining: 47.8s
# 287:	total: 1m 4s	remaining: 47.5s
# 288:	total: 1m 4s	remaining: 47.2s
# 289:	total: 1m 4s	remaining: 46.9s
# 290:	total: 1m 4s	remaining: 46.6s
# 291:	total: 1m 5s	remaining: 46.4s
# 292:	total: 1m 5s	remaining: 46.1s
# 293:	total: 1m 5s	remaining: 45.9s
# 294:	total: 1m 5s	remaining: 45.6s
# 295:	total: 1m 5s	remaining: 45.3s
# 296:	total: 1m 5s	remaining: 45.1s
# 297:	total: 1m 6s	remaining: 44.8s
# 298:	total: 1m 6s	remaining: 44.5s
# 299:	total: 1m 6s	remaining: 44.3s
# 300:	total: 1m 6s	remaining: 44s
# 301:	total: 1m 6s	remaining: 43.8s
# 302:	total: 1m 6s	remaining: 43.5s
# 303:	total: 1m 7s	remaining: 43.3s
# 304:	total: 1m 7s	remaining: 43s
# 305:	total: 1m 7s	remaining: 42.8s
# 306:	total: 1m 7s	remaining: 42.5s
# 307:	total: 1m 7s	remaining: 42.3s
# 308:	total: 1m 7s	remaining: 42s
# 309:	total: 1m 8s	remaining: 41.8s
# 310:	total: 1m 8s	remaining: 41.5s
# 311:	total: 1m 8s	remaining: 41.3s
# 312:	total: 1m 8s	remaining: 41s
# 313:	total: 1m 8s	remaining: 40.7s
# 314:	total: 1m 8s	remaining: 40.5s
# 315:	total: 1m 9s	remaining: 40.2s
# 316:	total: 1m 9s	remaining: 40s
# 317:	total: 1m 9s	remaining: 39.7s
# 318:	total: 1m 9s	remaining: 39.5s
# 319:	total: 1m 9s	remaining: 39.2s
# 320:	total: 1m 9s	remaining: 39s
# 321:	total: 1m 10s	remaining: 38.7s
# 322:	total: 1m 10s	remaining: 38.4s
# 323:	total: 1m 10s	remaining: 38.2s
# 324:	total: 1m 10s	remaining: 37.9s
# 325:	total: 1m 10s	remaining: 37.7s
# 326:	total: 1m 10s	remaining: 37.4s
# 327:	total: 1m 10s	remaining: 37.2s
# 328:	total: 1m 11s	remaining: 37s
# 329:	total: 1m 11s	remaining: 36.7s
# 330:	total: 1m 11s	remaining: 36.5s
# 331:	total: 1m 11s	remaining: 36.3s
# 332:	total: 1m 11s	remaining: 36.1s
# 333:	total: 1m 12s	remaining: 35.9s
# 334:	total: 1m 12s	remaining: 35.7s
# 335:	total: 1m 12s	remaining: 35.5s
# 336:	total: 1m 12s	remaining: 35.2s
# 337:	total: 1m 13s	remaining: 35s
# 338:	total: 1m 13s	remaining: 34.8s
# 339:	total: 1m 13s	remaining: 34.7s
# 340:	total: 1m 13s	remaining: 34.5s
# 341:	total: 1m 14s	remaining: 34.4s
# 342:	total: 1m 14s	remaining: 34.3s
# 343:	total: 1m 14s	remaining: 34s
# 344:	total: 1m 15s	remaining: 33.8s
# 345:	total: 1m 15s	remaining: 33.5s
# 346:	total: 1m 15s	remaining: 33.3s
# 347:	total: 1m 15s	remaining: 33s
# 348:	total: 1m 15s	remaining: 32.7s
# 349:	total: 1m 15s	remaining: 32.5s
# 350:	total: 1m 15s	remaining: 32.2s
# 351:	total: 1m 16s	remaining: 32s
# 352:	total: 1m 16s	remaining: 31.8s
# 353:	total: 1m 16s	remaining: 31.5s
# 354:	total: 1m 16s	remaining: 31.3s
# 355:	total: 1m 16s	remaining: 31s
# 356:	total: 1m 16s	remaining: 30.8s
# 357:	total: 1m 17s	remaining: 30.6s
# 358:	total: 1m 17s	remaining: 30.3s
# 359:	total: 1m 17s	remaining: 30.1s
# 360:	total: 1m 17s	remaining: 29.8s
# 361:	total: 1m 17s	remaining: 29.6s
# 362:	total: 1m 17s	remaining: 29.3s
# 363:	total: 1m 17s	remaining: 29.1s
# 364:	total: 1m 17s	remaining: 28.8s
# 365:	total: 1m 18s	remaining: 28.6s
# 366:	total: 1m 18s	remaining: 28.4s
# 367:	total: 1m 18s	remaining: 28.2s
# 368:	total: 1m 18s	remaining: 28s
# 369:	total: 1m 19s	remaining: 27.8s
# 370:	total: 1m 19s	remaining: 27.6s
# 371:	total: 1m 19s	remaining: 27.3s
# 372:	total: 1m 19s	remaining: 27.1s
# 373:	total: 1m 20s	remaining: 27s
# 374:	total: 1m 20s	remaining: 26.7s
# 375:	total: 1m 20s	remaining: 26.5s
# 376:	total: 1m 20s	remaining: 26.3s
# 377:	total: 1m 20s	remaining: 26.1s
# 378:	total: 1m 21s	remaining: 25.9s
# 379:	total: 1m 21s	remaining: 25.6s
# 380:	total: 1m 21s	remaining: 25.4s
# 381:	total: 1m 21s	remaining: 25.2s
# 382:	total: 1m 21s	remaining: 25s
# 383:	total: 1m 21s	remaining: 24.8s
# 384:	total: 1m 22s	remaining: 24.5s
# 385:	total: 1m 22s	remaining: 24.3s
# 386:	total: 1m 22s	remaining: 24.1s
# 387:	total: 1m 22s	remaining: 23.8s
# 388:	total: 1m 22s	remaining: 23.6s
# 389:	total: 1m 22s	remaining: 23.4s
# 390:	total: 1m 23s	remaining: 23.1s
# 391:	total: 1m 23s	remaining: 22.9s
# 392:	total: 1m 23s	remaining: 22.7s
# 393:	total: 1m 23s	remaining: 22.5s
# 394:	total: 1m 23s	remaining: 22.2s
# 395:	total: 1m 23s	remaining: 22s
# 396:	total: 1m 24s	remaining: 21.8s
# 397:	total: 1m 24s	remaining: 21.6s
# 398:	total: 1m 24s	remaining: 21.4s
# 399:	total: 1m 24s	remaining: 21.1s
# 400:	total: 1m 24s	remaining: 20.9s
# 401:	total: 1m 25s	remaining: 20.7s
# 402:	total: 1m 25s	remaining: 20.5s
# 403:	total: 1m 25s	remaining: 20.3s
# 404:	total: 1m 25s	remaining: 20.1s
# 405:	total: 1m 25s	remaining: 19.8s
# 406:	total: 1m 25s	remaining: 19.6s
# 407:	total: 1m 26s	remaining: 19.4s
# 408:	total: 1m 26s	remaining: 19.2s
# 409:	total: 1m 26s	remaining: 19s
# 410:	total: 1m 26s	remaining: 18.8s
# 411:	total: 1m 26s	remaining: 18.5s
# 412:	total: 1m 26s	remaining: 18.3s
# 413:	total: 1m 27s	remaining: 18.1s
# 414:	total: 1m 27s	remaining: 17.9s
# 415:	total: 1m 27s	remaining: 17.6s
# 416:	total: 1m 27s	remaining: 17.4s
# 417:	total: 1m 27s	remaining: 17.2s
# 418:	total: 1m 27s	remaining: 17s
# 419:	total: 1m 28s	remaining: 16.8s
# 420:	total: 1m 28s	remaining: 16.6s
# 421:	total: 1m 28s	remaining: 16.3s
# 422:	total: 1m 28s	remaining: 16.1s
# 423:	total: 1m 28s	remaining: 15.9s
# 424:	total: 1m 28s	remaining: 15.7s
# 425:	total: 1m 28s	remaining: 15.5s
# 426:	total: 1m 29s	remaining: 15.2s
# 427:	total: 1m 29s	remaining: 15s
# 428:	total: 1m 29s	remaining: 14.8s
# 429:	total: 1m 29s	remaining: 14.6s
# 430:	total: 1m 29s	remaining: 14.4s
# 431:	total: 1m 29s	remaining: 14.2s
# 432:	total: 1m 30s	remaining: 13.9s
# 433:	total: 1m 30s	remaining: 13.7s
# 434:	total: 1m 30s	remaining: 13.5s
# 435:	total: 1m 30s	remaining: 13.3s
# 436:	total: 1m 30s	remaining: 13.1s
# 437:	total: 1m 30s	remaining: 12.9s
# 438:	total: 1m 31s	remaining: 12.7s
# 439:	total: 1m 31s	remaining: 12.4s
# 440:	total: 1m 31s	remaining: 12.2s
# 441:	total: 1m 31s	remaining: 12s
# 442:	total: 1m 31s	remaining: 11.8s
# 443:	total: 1m 31s	remaining: 11.6s
# 444:	total: 1m 31s	remaining: 11.4s
# 445:	total: 1m 32s	remaining: 11.2s
# 446:	total: 1m 32s	remaining: 10.9s
# 447:	total: 1m 32s	remaining: 10.7s
# 448:	total: 1m 32s	remaining: 10.5s
# 449:	total: 1m 32s	remaining: 10.3s
# 450:	total: 1m 32s	remaining: 10.1s
# 451:	total: 1m 32s	remaining: 9.87s
# 452:	total: 1m 33s	remaining: 9.66s
# 453:	total: 1m 33s	remaining: 9.45s
# 454:	total: 1m 33s	remaining: 9.23s
# 455:	total: 1m 33s	remaining: 9.02s
# 456:	total: 1m 33s	remaining: 8.81s
# 457:	total: 1m 33s	remaining: 8.6s
# 458:	total: 1m 33s	remaining: 8.39s
# 459:	total: 1m 34s	remaining: 8.18s
# 460:	total: 1m 34s	remaining: 7.97s
# 461:	total: 1m 34s	remaining: 7.76s
# 462:	total: 1m 34s	remaining: 7.54s
# 463:	total: 1m 34s	remaining: 7.33s
# 464:	total: 1m 34s	remaining: 7.13s
# 465:	total: 1m 34s	remaining: 6.92s
# 466:	total: 1m 34s	remaining: 6.71s
# 467:	total: 1m 35s	remaining: 6.5s
# 468:	total: 1m 35s	remaining: 6.29s
# 469:	total: 1m 35s	remaining: 6.09s
# 470:	total: 1m 35s	remaining: 5.88s
# 471:	total: 1m 35s	remaining: 5.67s
# 472:	total: 1m 35s	remaining: 5.46s
# 473:	total: 1m 35s	remaining: 5.26s
# 474:	total: 1m 36s	remaining: 5.05s
# 475:	total: 1m 36s	remaining: 4.85s
# 476:	total: 1m 36s	remaining: 4.64s
# 477:	total: 1m 36s	remaining: 4.44s
# 478:	total: 1m 36s	remaining: 4.23s
# 479:	total: 1m 36s	remaining: 4.03s
# 480:	total: 1m 36s	remaining: 3.82s
# 481:	total: 1m 36s	remaining: 3.62s
# 482:	total: 1m 37s	remaining: 3.42s
# 483:	total: 1m 37s	remaining: 3.21s
# 484:	total: 1m 37s	remaining: 3.01s
# 485:	total: 1m 37s	remaining: 2.81s
# 486:	total: 1m 37s	remaining: 2.6s
# 487:	total: 1m 37s	remaining: 2.4s
# 488:	total: 1m 37s	remaining: 2.2s
# 489:	total: 1m 37s	remaining: 2s
# 490:	total: 1m 38s	remaining: 1.8s
# 491:	total: 1m 38s	remaining: 1.6s
# 492:	total: 1m 38s	remaining: 1.4s
# 493:	total: 1m 38s	remaining: 1.2s
# 494:	total: 1m 38s	remaining: 996ms
# 495:	total: 1m 38s	remaining: 796ms
# 496:	total: 1m 38s	remaining: 596ms
# 497:	total: 1m 38s	remaining: 397ms
# 498:	total: 1m 39s	remaining: 198ms
# 499:	total: 1m 39s	remaining: 0us
# GridSearchCV(cv=3,
#              estimator=<catboost.core.CatBoostClassifier object at 0x0000010EF7356290>,
#              n_jobs=-1,
#              param_grid={'depth': [6, 8], 'iterations': [500],
#                          'learning_rate': [0.01, 0.05]},
#              scoring='roc_auc', verbose=1)

# %%
# Access the best-tuned model
best_cbc = cbc_grid_search.best_estimator_

# %%
with open('classifier.pkl', 'wb') as file:
          pickle.dump(best_cbc, file)
